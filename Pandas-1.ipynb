# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
df = pd.read_csv("dataset/titanic.csv", skiprows = 0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.sort_values(by=["Name", "Pclass"])
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 730          731         1       1
# 4              5         0       3
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 834          835         0       3
# 192          193         1       3
# 460          461         1       1
# 850          851         0       3
# 813          814         0       3
# 119          120         0       3
# ...

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.plot(x='Age',  kind ="bar")

# %%
df["PassengerId2"] = df["PassengerId"] + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
help(df.plot)
# Out:
# Help on FramePlotMethods in module pandas.plotting._core object:
#
# class FramePlotMethods(BasePlotMethods)
#  |  DataFrame plotting accessor and method
#  |
#  |  Examples
#  |  --------
#  |  >>> df.plot.line()
#  |  >>> df.plot.scatter('x', 'y')
#  |  >>> df.plot.hexbin()
#  |
#  |  These plotting methods can also be accessed by calling the accessor as a
#  |  method with the ``kind`` argument:
#  |  ``df.plot(kind='line')`` is equivalent to ``df.plot.line()``
#  |
#  |  Method resolution order:
#  |      FramePlotMethods
#  |      BasePlotMethods
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
# ...

# %%
df.to_csv("dataset/titanic_new1.csv", sep = "|", header=True, index = False)

# %% [markdown]
# ## Basic Functions

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
# To sum all coulmns
df.mean(skipna=True,axis=0)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
# To get a data summary
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# To delete a column
#df.drop(["PassengerId"],axis=1,inplace=False)
#To delete a row
df.drop(0,axis=0)
df.to_excel("test.xlsx")

# %%
df.rename(columns={"PassengerId":"Id","Fare":"Amount"},index={})
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # Indexing and Selecting data
# pandas provides a suite of methods in order to get integer and label based indexing. The semantics follow closely python and numpy slicing

# %%
# To get columns 
df[["Fare","Survived", "Sex"]]
# Out:
#          Fare  Survived     Sex
# 0      7.2500         0    male
# 1     71.2833         1  female
# 2      7.9250         1  female
# 3     53.1000         1  female
# 4      8.0500         0    male
# 5      8.4583         0    male
# 6     51.8625         0    male
# 7     21.0750         0    male
# 8     11.1333         1  female
# 9     30.0708         1  female
# 10    16.7000         1  female
# 11    26.5500         1  female
# 12     8.0500         0    male
# 13    31.2750         0    male
# 14     7.8542         0  female
# 15    16.0000         1  female
# 16    29.1250         0    male
# 17    13.0000         1    male
# 18    18.0000         0  female
# 19     7.2250         1  female
# 20    26.0000         0    male
# 21    13.0000         1    male
# 22     8.0292         1  female
# 23    35.5000         1    male
# 24    21.0750         0  female
# 25    31.3875         1  female
# 26     7.2250         0    male
# 27   263.0000         0    male
# ...

# %%
# Get rows
df[2:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
#Get a cell
df[["Fare"]]
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
#          ...
# 861     11.5000
# 862     25.9292
# 863     69.5500
# 864     13.0000
# 865     13.0000
# 866     13.8583
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 871     52.5542
# 872      5.0000
# 873      9.0000
# 874     24.0000
# 875      7.2250
# 876      9.8458
# 877      7.8958
# 878      7.8958
# 879     83.1583
# 880     26.0000
# 881      7.8958
# 882     10.5167
# 883     10.5000
# 884      7.0500
# ...

# %% [markdown]
# ## .loc
# This is for selection by label
#
# dataframe.loc[row labels,column labels]

# %%
df.loc[0:4,:]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[0:5,"Name":"Ticket"]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# Name: Name, dtype: object

# %% [markdown]
# ## .iloc
# Selection by position

# %%
df.iloc[2,:]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.iloc[2:5,0:3]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %% [markdown]
# ## .ix
# Mixed indexing

# %%
df_new = pd.DataFrame(np.random.randn(4,4), columns=list('ABCD'), index=list('abcd'))
df_new
df_new.ix[1:4,1:2]
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   app.launch_new_instance()
#           B
# b -0.084171
# c -1.578922
# d -1.695878

# %%
df_new.ix["c":"d",0:]
# Out:
#           A         B         C         D
# c  0.379004 -0.106059 -0.659217 -0.958674
# d  0.834042  0.133053  0.972928  0.395216

# %% [markdown]
# ## Boolean indexing

# %%
df[(df["Age"]>50) & (df["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 94            95         0       3                     Coxon, Mr. Daniel
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 124          125         0       1           White, Mr. Percival Wayland
# 150          151         0       2            Bateman, Rev. Robert James
# 152          153         0       3                      Meo, Mr. Alfonzo
# 155          156         0       1           Williams, Mr. Charles Duane
# 170          171         0       1             Van der hoef, Mr. Wyckoff
# 174          175         0       1               Smith, Mr. James Clinch
# ...

# %%
df[(df["Fare"]>50 )| (df["Embarked"]=="S")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 29            30         0       3
# 31            32         1       1
# 33            34         0       2
# ...

# %% [markdown]
# # Group By: split-apply-combine

# %%
df.groupby(["Pclass"]).groups.keys()
# Out:
# [1, 2, 3]

# %%
df.groupby(["Pclass","Sex"]).groups.keys()
# Out:
# [(1L, 'female'),
#  (3L, 'female'),
#  (1L, 'male'),
#  (2L, 'female'),
#  (2L, 'male'),
#  (3L, 'male')]

# %%
df.groupby("Sex").get_group("male")
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
df.groupby("Pclass").count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked  PassengerId2
# Pclass
# 1         176       214           216
# 2          16       184           184
# 3          12       491           491

# %%
df.groupby("Pclass").mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare  \
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
#
#         PassengerId2
# Pclass
# 1         462.597222
# 2         446.956522
# 3         440.154786

# %%
df.groupby("Pclass").agg(np.median)
# Out:
#         PassengerId  Survived   Age  SibSp  Parch     Fare  PassengerId2
# Pclass
# 1             472.0       1.0  37.0    0.0    0.0  60.2875         473.0
# 2             435.5       0.0  29.0    0.0    0.0  14.2500         436.5
# 3             432.0       0.0  24.0    0.0    0.0   8.0500         433.0

# %%
df.groupby("Pclass").agg([np.sum,np.mean])
# Out:
#        PassengerId             Survived                Age            SibSp  \
#                sum        mean      sum      mean      sum       mean   sum
# Pclass
# 1            99705  461.597222      136  0.629630  7111.42  38.233441    90
# 2            82056  445.956522       87  0.472826  5168.83  29.877630    74
# 3           215625  439.154786      119  0.242363  8924.92  25.140620   302
#
#                  Parch                  Fare            PassengerId2  \
#             mean   sum      mean         sum       mean          sum
# Pclass
# 1       0.416667    77  0.356481  18177.4125  84.154687        99921
# 2       0.402174    70  0.380435   3801.8417  20.662183        82240
# 3       0.615071   193  0.393075   6714.6951  13.675550       216116
#
#
#               mean
# Pclass
# 1       462.597222
# 2       446.956522
# 3       440.154786

# %%
df.groupby("Pclass").agg({"Fare":lambda x : np.median(x),
                           "Age":np.median})
# Out:
#            Fare   Age
# Pclass
# 1       60.2875  37.0
# 2       14.2500  29.0
# 3        8.0500  24.0

# %%
df.hist(column = "Fare")
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D0FD320>]], dtype=object)

# %% [markdown]
# # Excercise 1
#
# House data from King's County
#
# - Get the basic statistics using describe
# - get the last 5 records using tail
# - get the second through 10 record using slicing
# - get the unique set of values dor the bedrooms column
# - return  only the price column
# - return only records where the prices > $200000  and the number of bedrooms == 3

# %%
kcData = pd.read_csv("dataset/kc_house_data.csv")
kcData
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %% [markdown]
# # Excercise 2
#
# - Obtain the median price by zip code

# %% [markdown]
# # Excercise 3
#
# - Open dataset/kc_housedata_2.csv & dataset/kc_housedata_10.csv
# - Stack them one on top of the other

# %%
kcData.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# # Answers to excercise 1

# %%
kcData.describe()
kcData.tail()
kcData.iloc [2:10]
kcData.bedrooms.unique()
kcData.price
kcData[(kcData.price > 200000) & (kcData.bedrooms == 3)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 12      114101516  20140528T000000   310000.0         3       1.00
# 13     6054650070  20141007T000000   400000.0         3       1.75
# 16     1875500060  20140731T000000   395000.0         3       2.00
# 19     7983200060  20150424T000000   230000.0         3       1.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# ...

# %% [markdown]
# # Answers to excercise 2

# %%
kcData.groupby("zipcode").median()
kcData.groupby("zipcode").agg({"price": np.median})
kcData.price.median()
# Out:
# 450000.0
